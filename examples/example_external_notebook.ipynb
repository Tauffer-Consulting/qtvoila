# %% [markdown]
# # This notebook was imported into my GUI application!
#
# Thanks QtVoila! =)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure()
plt.plot(np.random.rand(10), '-ok')
plt.show()

# %% [markdown]
# Above we see a random process in **black**, below we see a random process in <font color=red>**red**</font>:

# %%
plt.figure()
plt.plot(np.random.rand(10), '-or')
plt.show()
